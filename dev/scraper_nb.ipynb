# %% [markdown]
# ### Fanfulla 5a

# %%
import os
import pandas as pd
from bs4 import BeautifulSoup
import datetime
import lxml

# %% [markdown]
# Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
options = webdriver.ChromeOptions()
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36')
options.add_argument('--headless')
driver = webdriver.Chrome(executable_path=r'C:\Users\anton\OneDrive\Desktop\Projects\PulseRome\chromedriver.exe', options=options)
driver.get("http://www.fanfulla5a.it/2023/06/01/programma-giugno-2023/")
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
# Out:
# C:\Users\anton\AppData\Local\Temp\ipykernel_12492\207507712.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\anton\OneDrive\Desktop\Projects\PulseRome\chromedriver.exe', options=options)

# %% [markdown]
# Requests

# %%
import requests
html = requests.get("http://www.fanfulla5a.it/2023/06/01/programma-giugno-2023/").content
soup = BeautifulSoup(html, "lxml")

# %%
# day = soup.find('div', class_='siteorigin-widget-tinymce').find('h3').text
# day = day.split(' ')[1]
# day = datetime.datetime.strptime(f'{day} {datetime.datetime.now().month} {datetime.datetime.now().year}', '%d %m %Y')
# title = soup.find('div', class_='siteorigin-widget-tinymce').find('h4').text
# location = 'Fanfulla 5/A Circolo Arci'
# time = soup.find('div', class_='siteorigin-widget-tinymce').find('span', class_='_4n-j fsl').text
# time = time.split('dalle ore ')[1]
# time = datetime.datetime.strptime(time, '%H')
# time = time.strftime('%H:%M')
# date_and_time = day.replace(hour=int(time.split(':')[0]), minute=int(time.split(':')[1]))
# url = soup.find('div', class_='siteorigin-widget-tinymce').find_all('a')[-1]['href']
# print("The event is on " + day.strftime("%d/%m/%Y") + " at " + time + " in " + location + " and is called " + title + ". The url is " + url + ".")
# Out:
# The event is on 01/08/2023 at 22:00 in Fanfulla 5/A Circolo Arci and is called Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr). The url is https://www.facebook.com/events/1224327351594293/.

# %%
events = soup.find_all('div', class_='siteorigin-widget-tinymce')
events_list = []

for event in events:
    event_dict = {}
    try:
        day = event.find('h3').text.split(' ')[1]
        day = datetime.datetime.strptime(f'{day} {datetime.datetime.now().month} {datetime.datetime.now().year}', '%d %m %Y')
    except:
        continue
    event_dict["title"] = event.find('h4').text
    event_dict["location"] = 'Fanfulla 5/A Circolo Arci'
    time = event.find('span', class_='_4n-j fsl').text.split('dalle ore ')[1]
    time = datetime.datetime.strptime(time, '%H').strftime('%H:%M')
    event_dict["date_and_time"] = day.replace(hour=int(time.split(':')[0]), minute=int(time.split(':')[1]))
    event_dict["url"] = event.find_all('a')[-1]['href']
    events_list.append(event_dict)
    print(events_list)

df = pd.DataFrame(events_list)
# df['date'] = df['date_and_time'].apply(lambda x: x.date())
# df['time'] = df['date_and_time'].apply(lambda x: x.time().strftime('%H:%M'))
# df['year'] = df['date_and_time'].apply(lambda x: x.year)
# df['month'] = df['date_and_time'].apply(lambda x: x.month)
# df['day'] = df['date_and_time'].apply(lambda x: x.day)
# df.drop('date_and_time', axis=1, inplace=True)
df = df[['date_and_time','title', 'location', 'url']]
# Out:
# [{'title': 'Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 1, 22, 0), 'url': 'https://www.facebook.com/events/1224327351594293/'}]
# [{'title': 'Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 1, 22, 0), 'url': 'https://www.facebook.com/events/1224327351594293/'}, {'title': 'BNSSR dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 2, 22, 0), 'url': 'https://www.facebook.com/events/1014511849572895/'}]
# [{'title': 'Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 1, 22, 0), 'url': 'https://www.facebook.com/events/1224327351594293/'}, {'title': 'BNSSR dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 2, 22, 0), 'url': 'https://www.facebook.com/events/1014511849572895/'}, {'title': 'NZE NZE (Paris, Fr - Live / From UVB76 & Sacred Lodge) + Vic Sinex dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 3, 22, 0), 'url': 'https://www.facebook.com/events/784908279699020/'}]
# [{'title': 'Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 1, 22, 0), 'url': 'https://www.facebook.com/events/1224327351594293/'}, {'title': 'BNSSR dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 2, 22, 0), 'url': 'https://www.facebook.com/events/1014511849572895/'}, {'title': 'NZE NZE (Paris, Fr - Live / From UVB76 & Sacred Lodge) + Vic Sinex dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 3, 22, 0), 'url': 'https://www.facebook.com/events/784908279699020/'}, {'title': 'EDDA GABER - Teatri Improrogabili: “Malato di Brutto” + Steve Pepe dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 4, 22, 0), 'url': 'https://www.facebook.com/events/797613481711251/'}]
# [{'title': 'Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 1, 22, 0), 'url': 'https://www.facebook.com/events/1224327351594293/'}, {'title': 'BNSSR dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 2, 22, 0), 'url': 'https://www.facebook.com/events/1014511849572895/'}, {'title': 'NZE NZE (Paris, Fr - Live / From UVB76 & Sacred Lodge) + Vic Sinex dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 3, 22, 0), 'url': 'https://www.facebook.com/events/784908279699020/'}, {'title': 'EDDA GABER - Teatri Improrogabili: “Malato di Brutto” + Steve Pepe dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 4, 22, 0), 'url': 'https://www.facebook.com/events/797613481711251/'}, {'title': 'Arrington De Dionyso (Old Time Relijun) + Pier Panico dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 5, 22, 0), 'url': 'https://www.facebook.com/events/757502552733924/'}]
# [{'title': 'Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 1, 22, 0), 'url': 'https://www.facebook.com/events/1224327351594293/'}, {'title': 'BNSSR dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 2, 22, 0), 'url': 'https://www.facebook.com/events/1014511849572895/'}, {'title': 'NZE NZE (Paris, Fr - Live / From UVB76 & Sacred Lodge) + Vic Sinex dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 3, 22, 0), 'url': 'https://www.facebook.com/events/784908279699020/'}, {'title': 'EDDA GABER - Teatri Improrogabili: “Malato di Brutto” + Steve Pepe dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 4, 22, 0), 'url': 'https://www.facebook.com/events/797613481711251/'}, {'title': 'Arrington De Dionyso (Old Time Relijun) + Pier Panico dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 5, 22, 0), 'url': 'https://www.facebook.com/events/757502552733924/'}, {'title': 'Kinema Fanfulla - WORK THAT LOVE - “Pride” di Matthew Warchus (UK 2014)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 6, 21, 0), 'url': 'https://portale.arci.it/preadesione/fanfulla/?fbclid=IwAR2axYH9cHSuKdm9FoNF1Af09f5B3K0az2bpyH19KY50D_Wm3_JzeIoFL84'}]
# [{'title': 'Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 1, 22, 0), 'url': 'https://www.facebook.com/events/1224327351594293/'}, {'title': 'BNSSR dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 2, 22, 0), 'url': 'https://www.facebook.com/events/1014511849572895/'}, {'title': 'NZE NZE (Paris, Fr - Live / From UVB76 & Sacred Lodge) + Vic Sinex dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 3, 22, 0), 'url': 'https://www.facebook.com/events/784908279699020/'}, {'title': 'EDDA GABER - Teatri Improrogabili: “Malato di Brutto” + Steve Pepe dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 4, 22, 0), 'url': 'https://www.facebook.com/events/797613481711251/'}, {'title': 'Arrington De Dionyso (Old Time Relijun) + Pier Panico dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 5, 22, 0), 'url': 'https://www.facebook.com/events/757502552733924/'}, {'title': 'Kinema Fanfulla - WORK THAT LOVE - “Pride” di Matthew Warchus (UK 2014)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 6, 21, 0), 'url': 'https://portale.arci.it/preadesione/fanfulla/?fbclid=IwAR2axYH9cHSuKdm9FoNF1Af09f5B3K0az2bpyH19KY50D_Wm3_JzeIoFL84'}, {'title': 'The Telescopes (UK - Live) + Drum Girl & Guitar Boy dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 7, 22, 0), 'url': 'https://www.facebook.com/events/3415241015425528'}]
# [{'title': 'Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 1, 22, 0), 'url': 'https://www.facebook.com/events/1224327351594293/'}, {'title': 'BNSSR dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 2, 22, 0), 'url': 'https://www.facebook.com/events/1014511849572895/'}, {'title': 'NZE NZE (Paris, Fr - Live / From UVB76 & Sacred Lodge) + Vic Sinex dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 3, 22, 0), 'url': 'https://www.facebook.com/events/784908279699020/'}, {'title': 'EDDA GABER - Teatri Improrogabili: “Malato di Brutto” + Steve Pepe dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 4, 22, 0), 'url': 'https://www.facebook.com/events/797613481711251/'}, {'title': 'Arrington De Dionyso (Old Time Relijun) + Pier Panico dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 5, 22, 0), 'url': 'https://www.facebook.com/events/757502552733924/'}, {'title': 'Kinema Fanfulla - WORK THAT LOVE - “Pride” di Matthew Warchus (UK 2014)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 6, 21, 0), 'url': 'https://portale.arci.it/preadesione/fanfulla/?fbclid=IwAR2axYH9cHSuKdm9FoNF1Af09f5B3K0az2bpyH19KY50D_Wm3_JzeIoFL84'}, {'title': 'The Telescopes (UK - Live) + Drum Girl & Guitar Boy dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 7, 22, 0), 'url': 'https://www.facebook.com/events/3415241015425528'}, {'title': 'FEMININE dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 8, 22, 0), 'url': 'https://www.facebook.com/events/962475938223899/'}]
# [{'title': 'Simmcat (Roma - Live) + Charlène Darling (Fr - Opening) + DJ Féecale (Fr)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 1, 22, 0), 'url': 'https://www.facebook.com/events/1224327351594293/'}, {'title': 'BNSSR dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8,
 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 9, 22, 0), 'url': 'https://www.facebook.com/events/580530394210955'}, {'title': 'MISTO MAME Feat. Jazzoux (Fr) + Carrageenan (Belgio) + Dolores (Fr) - Thurston Mourad dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 10, 22, 0), 'url': 'https://www.facebook.com/events/1386849108544208/'}, {'title': 'LATAM FUTURO Off [Mala Fama (EC) Live X Condoii (EC/IT) djset \\\\ Mamacoca Live X La Diferencia ]', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 11, 22, 0), 'url': 'https://www.facebook.com/events/3431147533820654/'}, {'title': 'Yosa Peit (Berlin / Fire Records - Live) + Pier Panico dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 12, 22, 0), 'url': 'https://www.facebook.com/events/570884598492608/'}, {'title': 'Kinema Fanfulla - WORK THAT LOVE - “Beau Travail” di Claire Denis (Francia, 1999)', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 13, 21, 0), 'url': 'https://portale.arci.it/preadesione/fanfulla/?fbclid=IwAR2axYH9cHSuKdm9FoNF1Af09f5B3K0az2bpyH19KY50D_Wm3_JzeIoFL84'}, {'title': 'Polonius (Fr/Egypt - Live) + Azione Romantica (Sandra Mason + LKSM) dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 14, 22, 0), 'url': 'https://www.facebook.com/events/1971971586476125/'}, {'title': 'HOTLINE TNT (Live - USA) + GLM dj set', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 15, 22, 0), 'url': 'https://www.facebook.com/events/974793360614460/'}, {'title': 'SINCE Nel Bosco - Anteprima', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': datetime.datetime(2023, 8, 16, 22, 0), 'url': 'https://www.facebook.com/events/539206528245995/'}, {'title': 'MAKE R/ M AGAIN feat. TAJ KAJAL DWELLERS / YUKIKO MATSUKURA / CIRO FANELLI', 'location': 'Fanfulla 5/A Circolo Arci', 'date_and_time': d ...
#          date  year  month  day   time  \
# 0  2023-08-01  2023      8    1  22:00
# 1  2023-08-02  2023      8    2  22:00
# 2  2023-08-03  2023      8    3  22:00
# 3  2023-08-04  2023      8    4  22:00
# 4  2023-08-05  2023      8    5  22:00
#
#                                                title  \
# 0  Simmcat (Roma - Live) + Charlène Darling (Fr -...
# 1                                       BNSSR dj set
# 2  NZE NZE (Paris, Fr - Live / From UVB76 & Sacre...
# 3  EDDA GABER - Teatri Improrogabili: “Malato di ...
# 4  Arrington De Dionyso (Old Time Relijun) + Pier...
#
#                     location  \
# 0  Fanfulla 5/A Circolo Arci
# 1  Fanfulla 5/A Circolo Arci
# 2  Fanfulla 5/A Circolo Arci
# 3  Fanfulla 5/A Circolo Arci
# 4  Fanfulla 5/A Circolo Arci
#
#                                                  url
# 0  https://www.facebook.com/events/1224327351594293/
# 1  https://www.facebook.com/events/1014511849572895/
# 2   https://www.facebook.com/events/784908279699020/
# 3   https://www.facebook.com/events/797613481711251/
# 4   https://www.facebook.com/events/757502552733924/

# %%
set(pd.to_datetime(df["date"]).dt.month_name().values)
# Out:
# {'August'}

# %% [markdown]
# ### RA - Related events test

# %%
import json
import requests

query = """
query GET_RELATED_AREA($areaId: ID, $dateFrom: DateTime, $dateTo: DateTime, $count: Int!) {
  area(id: $areaId) {
    id
    name
    urlName
    country {
      id
      name
      urlCode
      __typename
    }
    __typename
  }
  events(limit: $count, type: POPULAR, areaId: $areaId, dateFrom: $dateFrom, dateTo: $dateTo) {
    id
    title
    attending
    date
    contentUrl
    flyerFront
    queueItEnabled
    newEventForm
    images {
      id
      filename
      alt
      type
      crop
      __typename
    }
    area {
      id
      name
      urlName
      country {
        id
        name
        urlCode
        __typename
      }
      __typename
    }
    venue {
      id
      name
      contentUrl
      live
      __typename
    }
    __typename
  }
  venues(limit: $count, areaId: $areaId, orderBy: POPULAR) {
    id
    name
    logoUrl
    isFollowing
    contentUrl
    followerCount
    __typename
  }
  picks: events(limit: $count, type: PICKS, areaId: $areaId) {
    id
    title
    attending
    date
    contentUrl
    queueItEnabled
    venue {
      id
      name
      contentUrl
      live
      __typename
    }
    pick {
      id
      blurb
      __typename
    }
    __typename
  }
}
"""

json_data = {
    'query': query,
    'variables': {
        'areaId': "351",
        'count': 100,
        'dateFrom': "2023-08-07",
        'dateTo': "2023-08-13",
    },
    'operationName': 'GET_RELATED_AREA',
}

headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'it-IT,it;q=0.5',
    'Content-Length': '1447',
    'Content-Type': 'application/json',
    'Cookie': 'genre=...; ravelinDeviceId=rjs-ecce1a63-a412-483a-9049-34f1df11ecd8; ra_content_language=en; ravelinSessionId=rjs-ecce1a63-a412-483a-9049-34f1df11ecd8:5f8a5610-2ed1-4b8e-a262-ab2cf949ccd3; lvl1=ec2; lvl2=7c60b3bba29595a9; ASP.NET_SessionId=qoheystiyxfssmimedlbih3v; RALang=it; sid=31cb676b-6bdf-423e-a1ce-2220688cacb5; mp_92ee4b4275be9eef375a8c024ded64c3_mixpanel=%7B%22distinct_id%22%3A%20%22189a7946d5dcdc-01535fee342337-26031c51-121b04-189a7946d5e10c9%22%2C%22%24device_id%22%3A%20%22189a7946d5dcdc-01535fee342337-26031c51-121b04-189a7946d5e10c9%22%2C%22%24search_engine%22%3A%20%22duckduckgo%22%2C%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fwww.google.it%2F%22%2C%22%24initial_referring_domain%22%3A%20%22www.google.it%22%2C%22ExperimentData%22%3A%20%5B%0A%20%20%20%20%22Enabling%20Festivals%20in%20global%20navigation%3Adisabled%22%2C%0A%20%20%20%20%22Hide%20interested%20(roll%20call)%20count%3Adisabled%22%2C%0A%20%20%20%20%22Promoter%20ticket%20fee%20type%3Adisabled%22%2C%0A%20%20%20%20%22Personalized%20popular%20event%20listings%20for%20logged%20in%20users%3Adisabled%22%2C%0A%20%20%20%20%22Enabling%20cookie%20consent%20banners%3ATop%22%2C%0A%20%20%20%20%22Enabling%20Fourth%20Link%20in%20global%20navigation%3Aoff%22%0A%5D%7D; ra_mp_experimentdata=%5B%22Enabling%20Festivals%20in%20global%20navigation%3Adisabled%22%2C%22Hide%20interested%20(roll%20call)%20count%3Adisabled%22%2C%22Promoter%20ticket%20fee%20type%3Adisabled%22%2C%22Personalized%20popular%20event%20listings%20for%20logged%20in%20users%3Adisabled%22%2C%22Enabling%20cookie%20consent%20banners%3ATop%22%2C%22Enabling%20Fourth%20Link%20in%20global%20navigation%3Aoff%22%5D; datadome=5vxsxbkmbI8-ByXDXV2Cy57u7N9ekZmyZFxn~2FwVF6sCXWP0o5bPOEJUzPVeoDpAwqR63bVFFdaMGo7-W5VarWIiqU56T~ROYzp88WN_sXUSfuuk5r4ec~MWhMZh_ei; __cf_bm=mIZPwp3wi_Pc6R9yNC2ixw9y10sNiaUdDp3Q_6PuuVI-1691442723-0-AVAK/mpvGw9MpppAvVVclF25+F4LLGueslOmh1cVHPADwoq01aOTvT623nzA6i+YPOT+w+3Sw7dlYEmcV4c9LdM=',
    'Origin': 'https://ra.co',
    'Ra-Content-Language': 'en',
    'Referer': 'https://ra.co/clubs/190667',
    'Sec-Ch-Ua': '"Not/A)Brand";v="99", "Brave";v="115", "Chromium";v="115"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Model': '""',
    'Sec-Ch-Ua-Platform': '"Windows"',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.1155.0 Safari/537.36',
    'X-Access-Control-Allow-Origin': 'https://ra.co',
    'X-Apollo-Tracing': '1',
    'X-Bazaarvoice-Api': '1',
}

response = requests.post('https://ra.co/graphql', json=json_data, headers=headers)

# Handling the response
if response.status_code == 200:
    # Successfully received response
    print(json.dumps(response.json(), indent=2))
else:
    # Handle error
    print(response.status_code, response.text)

print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "errors": [
#     {
#       "message": "Limit must not be greater than 20",
#       "locations": [
#         {
#           "line": 53,
#           "column": 3
#         }
#       ],
#       "path": [
#         "venues"
#       ]
#     }
#   ],
#   "data": {
#     "area": {
#       "id": "351",
#       "name": "Rome",
#       "urlName": "rome",
#       "country": {
#         "id": "20",
#         "name": "Italy",
#         "urlCode": "IT",
#         "__typename": "Country"
#       },
#       "__typename": "Area"
#     },
#     "events": [
#       {
#         "id": "1739863",
#         "title": "Thefiugees presents",
#         "attending": 19,
#         "date": "2023-08-12T00:00:00.000",
#         "contentUrl": "/events/1739863",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "319140",
#             "filename": "https://images.ra.co/28e548de08209d53b02ed6fe05315fbdb7ba1479.jpg",
#             "alt": "20h party",
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "194468",
#           "name": "TBA",
#           "contentUrl": null,
#           "live": false,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1752451",
#         "title": "Electronic Garden: Francesco Maria, Daniele Pavoni, Diana, ADELAID",
#         "attending": 2,
#         "date": "2023-08-09T00:00:00.000",
#         "contentUrl": "/events/1752451",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "336327",
#             "filename": "https://images.ra.co/ff6acda36051efe96f707d89b47fb029648b5ab3.jpg",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "139767",
#           "name": "Hotel Butterfly",
#           "contentUrl": "/clubs/139767",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1752506",
#         "title": "L' APERITIVO ELETTRONICO e POCKET PANTHER RECORDS",
#         "attending": 2,
#         "date": "2023-08-08T00:00:00.000",
#         "contentUrl": "/events/1752506",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "336400",
#             "filename": "https://images.ra.co/fd863dd9710823c2138a484a27ca9c3b53aff01d.jpg",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           },
#           {
#             "id": "336401",
#             "filename": "https://images.ra.co/713798e65e5a22a9d19d0b94cf44ff32999fdd34.jpg",
#             "alt": null,
#             "type": "FLYERBACK",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "27316",
#           "name": "Lettere Caff\u00e8",
#           "contentUrl": "/clubs/27316",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1752197",
#         "title": "Goa Ultrabeat: Cirillo, Giorgio Gigli, Lorenzo Dada",
#         "attending": 1,
#         "date": "2023-08-10T00:00:00.000",
#         "contentUrl": "/events/1752197",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "336013",
#             "filename": "https://images.ra.co/1818573db9821530e7ed00c41acfe494a2c62545.png",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "139767",
#           "name": "Hotel Butterfly",
#           "contentUrl": "/clubs/139767",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1753173",
#         "title": "EXTRA DATE",
#         "attending": 0,
#         "date": "2023-08-12T00:00:00.000",
#         "contentUrl": "/events/1753173",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "337332",
#             "filename": "https://images.ra.co/171ee25c5ba9fbacbb8b52d745954878e5b5de13.jpg",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "9119",
#           "name": "Neo Club",
#           "contentUrl": "/clubs/9119",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1753248",
#         "title": "EXTRA DATE",
#         "attending": 0,
#         "date": "2023-08-11T00:00:00.000",
#         "contentUrl": "/events/1753248",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "337784",
#             "filename": "https://images.ra.co/4f1d2f54bfb2a4682f03527ba2e4f7225b3f6ff7.jpg",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "9119",
#           "name": "Neo Club",
#           "contentUrl": "/clubs/9119",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       }
#     ],
#     "venues": [],
#     "picks": [
#       {
#         "id": "1662805",
#         "title": "Sumdayz Festival 2023",
#         "attending": 79,
#         "date": "2023-09-22T00:00:00.000",
#         "contentUrl": "/events/1662805",
#         "queueItEnabled": false,
#         "venue": {
#           "id": "11079",
#           "name": "Ippodromo Delle Capannelle",
#           "contentUrl": "/clubs/11079",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "pick": {
#           "id": "21094",
#           "blurb": "Partying outdoors in Rome in the autumn is worth the price of admission alone. The classy lineup\u2014which includes Craig Richards, tINI and Dyed Soundorom\u2014is a tasty bonus.",
#           "__typename": "EventPick"
#         },
#         "__typename": "Event"
#       }
#     ]
#   }
# }
# {
#   "errors": [
#     {
#       "message": "Limit must not be greater than 20",
#       "locations": [
#         {
#           "line": 53,
#           "column": 3
#         }
#       ],
#       "path": [
#         "venues"
#       ]
#     }
#   ],
#   "data": {
#     "area": {
#       "id": "351",
#       "name": "Rome",
#       "urlName": "rome",
#       "country": {
#         "id": "20",
#         "name": "Italy",
#         "urlCode": "IT",
#         "__typename": "Country"
#       },
#       "__typename": "Area"
#     },
#     "events": [
#       {
#         "id": "1739863",
#         "title": "Thefiugees presents",
#         "attending": 19,
#         "date": "2023-08-12T00:00:00.000",
#         "contentUrl": "/events/1739863",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "319140",
#             "filename": "https://images.ra.co/28e548de08209d53b02ed6fe05315fbdb7ba1479.jpg",
#             "alt": "20h party",
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "194468",
#           "name": "TBA",
#           "contentUrl": null,
#           "live": false,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1752451",
#         "title": "Electronic Garden: Francesco Maria, Daniele Pavoni, Diana, ADELAID",
#         "attending": 2,
#         "date": "2023-08-09T00:00:00.000",
#         "contentUrl": "/events/1752451",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "336327",
#             "filename": "https://images.ra.co/ff6acda36051efe96f707d89b47fb029648b5ab3.jpg",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "139767",
#           "name": "Hotel Butterfly",
#           "contentUrl": "/clubs/139767",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1752506",
#         "title": "L' APERITIVO ELETTRONICO e POCKET PANTHER RECORDS",
#         "attending": 2,
#         "date": "2023-08-08T00:00:00.000",
#         "contentUrl": "/events/1752506",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "336400",
#             "filename": "https://images.ra.co/fd863dd9710823c2138a484a27ca9c3b53aff01d.jpg",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           },
#           {
#             "id": "336401",
#             "filename": "https://images.ra.co/713798e65e5a22a9d19d0b94cf44ff32999fdd34.jpg",
#             "alt": null,
#             "type": "FLYERBACK",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "27316",
#           "name": "Lettere Caff\u00e8",
#           "contentUrl": "/clubs/27316",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1752197",
#         "title": "Goa Ultrabeat: Cirillo, Giorgio Gigli, Lorenzo Dada",
#         "attending": 1,
#         "date": "2023-08-10T00:00:00.000",
#         "contentUrl": "/events/1752197",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "336013",
#             "filename": "https://images.ra.co/1818573db9821530e7ed00c41acfe494a2c62545.png",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "139767",
#           "name": "Hotel Butterfly",
#           "contentUrl": "/clubs/139767",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1753173",
#         "title": "EXTRA DATE",
#         "attending": 0,
#         "date": "2023-08-12T00:00:00.000",
#         "contentUrl": "/events/1753173",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "337332",
#             "filename": "https://images.ra.co/171ee25c5ba9fbacbb8b52d745954878e5b5de13.jpg",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "9119",
#           "name": "Neo Club",
#           "contentUrl": "/clubs/9119",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       },
#       {
#         "id": "1753248",
#         "title": "EXTRA DATE",
#         "attending": 0,
#         "date": "2023-08-11T00:00:00.000",
#         "contentUrl": "/events/1753248",
#         "flyerFront": null,
#         "queueItEnabled": false,
#         "newEventForm": true,
#         "images": [
#           {
#             "id": "337784",
#             "filename": "https://images.ra.co/4f1d2f54bfb2a4682f03527ba2e4f7225b3f6ff7.jpg",
#             "alt": null,
#             "type": "FLYERFRONT",
#             "crop": null,
#             "__typename": "EventImage"
#           }
#         ],
#         "area": {
#           "id": "351",
#           "name": "Rome",
#           "urlName": "rome",
#           "country": {
#             "id": "20",
#             "name": "Italy",
#             "urlCode": "IT",
#             "__typename": "Country"
#           },
#           "__typename": "Area"
#         },
#         "venue": {
#           "id": "9119",
#           "name": "Neo Club",
#           "contentUrl": "/clubs/9119",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "__typename": "Event"
#       }
#     ],
#     "venues": [],
#     "picks": [
#       {
#         "id": "1662805",
#         "title": "Sumdayz Festival 2023",
#         "attending": 79,
#         "date": "2023-09-22T00:00:00.000",
#         "contentUrl": "/events/1662805",
#         "queueItEnabled": false,
#         "venue": {
#           "id": "11079",
#           "name": "Ippodromo Delle Capannelle",
#           "contentUrl": "/clubs/11079",
#           "live": true,
#           "__typename": "Venue"
#         },
#         "pick": {
#           "id": "21094",
#           "blurb": "Partying outdoors in Rome in the autumn is worth the price of admission alone. The classy lineup\u2014which includes Craig Richards, tINI and Dyed Soundorom\u2014is a tasty bonus.",
#           "__typename": "EventPick"
#         },
#         "__typename": "Event"
#       }
#     ]
#   }
# }

# %% [markdown]
# ### RA - Venue events from dictionary

# %%
import requests
import pandas as pd
import time
from datetime import date
from dateutil.relativedelta import relativedelta


clubs = { # ids must be strings to performa the request correctly
    'forte-antenne': '190667',
    'hotel-butterfly': '139767'
}

# Creating an empty list to store the flattened events for all clubs
flattened_events = []

# Looping through the clubs
for club_name, club_value in clubs.items():
    
    headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'it-IT,it;q=0.5',
    'Content-Length': '1447',
    'Content-Type': 'application/json',
    'Cookie': 'genre=...; ravelinDeviceId=rjs-ecce1a63-a412-483a-9049-34f1df11ecd8; ra_content_language=en; ravelinSessionId=rjs-ecce1a63-a412-483a-9049-34f1df11ecd8:5f8a5610-2ed1-4b8e-a262-ab2cf949ccd3; lvl1=ec2; lvl2=7c60b3bba29595a9; ASP.NET_SessionId=qoheystiyxfssmimedlbih3v; RALang=it; sid=31cb676b-6bdf-423e-a1ce-2220688cacb5; mp_92ee4b4275be9eef375a8c024ded64c3_mixpanel=%7B%22distinct_id%22%3A%20%22189a7946d5dcdc-01535fee342337-26031c51-121b04-189a7946d5e10c9%22%2C%22%24device_id%22%3A%20%22189a7946d5dcdc-01535fee342337-26031c51-121b04-189a7946d5e10c9%22%2C%22%24search_engine%22%3A%20%22duckduckgo%22%2C%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fwww.google.it%2F%22%2C%22%24initial_referring_domain%22%3A%20%22www.google.it%22%2C%22ExperimentData%22%3A%20%5B%0A%20%20%20%20%22Enabling%20Festivals%20in%20global%20navigation%3Adisabled%22%2C%0A%20%20%20%20%22Hide%20interested%20(roll%20call)%20count%3Adisabled%22%2C%0A%20%20%20%20%22Promoter%20ticket%20fee%20type%3Adisabled%22%2C%0A%20%20%20%20%22Personalized%20popular%20event%20listings%20for%20logged%20in%20users%3Adisabled%22%2C%0A%20%20%20%20%22Enabling%20cookie%20consent%20banners%3ATop%22%2C%0A%20%20%20%20%22Enabling%20Fourth%20Link%20in%20global%20navigation%3Aoff%22%0A%5D%7D; ra_mp_experimentdata=%5B%22Enabling%20Festivals%20in%20global%20navigation%3Adisabled%22%2C%22Hide%20interested%20(roll%20call)%20count%3Adisabled%22%2C%22Promoter%20ticket%20fee%20type%3Adisabled%22%2C%22Personalized%20popular%20event%20listings%20for%20logged%20in%20users%3Adisabled%22%2C%22Enabling%20cookie%20consent%20banners%3ATop%22%2C%22Enabling%20Fourth%20Link%20in%20global%20navigation%3Aoff%22%5D; datadome=5vxsxbkmbI8-ByXDXV2Cy57u7N9ekZmyZFxn~2FwVF6sCXWP0o5bPOEJUzPVeoDpAwqR63bVFFdaMGo7-W5VarWIiqU56T~ROYzp88WN_sXUSfuuk5r4ec~MWhMZh_ei; __cf_bm=mIZPwp3wi_Pc6R9yNC2ixw9y10sNiaUdDp3Q_6PuuVI-1691442723-0-AVAK/mpvGw9MpppAvVVclF25+F4LLGueslOmh1cVHPADwoq01aOTvT623nzA6i+YPOT+w+3Sw7dlYEmcV4c9LdM=',
    'Origin': 'https://ra.co',
    'Ra-Content-Language': 'en',
    'Referer': 'https://ra.co/clubs/{club_value}/events',
    'Sec-Ch-Ua': '"Not/A)Brand";v="99", "Brave";v="115", "Chromium";v="115"',
    'Sec-Ch-Ua-Mobile': '?0',
    'Sec-Ch-Ua-Model': '""',
    'Sec-Ch-Ua-Platform': '"Windows"',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.1155.0 Safari/537.36',
    'X-Access-Control-Allow-Origin': 'https://ra.co',
    'X-Apollo-Tracing': '1',
    'X-Bazaarvoice-Api': '1',
    }

    json_data = {
        "operationName": "GET_DEFAULT_EVENTS_LISTING",
        "variables": {
            "indices": ["EVENT"],
            "pageSize": 20,
            "page": 1,
            "aggregations": [],
            "filters": [{"type": "CLUB", "value": club_value},
                        {"type": "DATERANGE", "value": f"{{\"gte\":\"{date.today().strftime('%Y-%m-%dT00:00:00.000Z')}\"}}"},
                        {"type": "DATERANGE", "value": f"{{\"lte\":\"{(date.today() + relativedelta(day=+31)).strftime('%Y-%m-%dT00:00:00.000Z')}\"}}"}
                        ],
            "sortOrder": "ASCENDING",
            "sortField": "DATE",
            "baseFilters": [{"type": "CLUB", "value": club_value},
                            {"type": "DATERANGE", "value": f"{{\"gte\":\"{date.today().strftime('%Y-%m-%dT00:00:00.000Z')}\"}}"},
                            {"type": "DATERANGE", "value": f"{{\"lte\":\"{(date.today() + relativedelta(day=+31)).strftime('%Y-%m-%dT00:00:00.000Z')}\"}}"}
                            ]
        },
        "query":"query GET_DEFAULT_EVENTS_LISTING($indices: [IndexType!], $aggregations: [ListingAggregationType!], $filters: [FilterInput], $pageSize: Int, $page: Int, $sortField: FilterSortFieldType, $sortOrder: FilterSortOrderType, $baseFilters: [FilterInput]) {\n  listing(indices: $indices, aggregations: [], filters: $filters, pageSize: $pageSize, page: $page, sortField: $sortField, sortOrder: $sortOrder) {\n    data {\n      ...eventFragment\n      __typename\n    }\n    totalResults\n    __typename\n  }\n  aggregations: listing(indices: $indices, aggregations: $aggregations, filters: $baseFilters, pageSize: 0, sortField: $sortField, sortOrder: $sortOrder) {\n    aggregations {\n      type\n      values {\n        value\n        name\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment eventFragment on IListingItem {\n  ... on Event {\n    id\n    title\n    attending\n    date\n    startTime\n    contentUrl\n    queueItEnabled\n    flyerFront\n    newEventForm\n    images {\n      id\n      filename\n      alt\n      type\n      crop\n      __typename\n    }\n    artists {\n      id\n      name\n      __typename\n    }\n    venue {\n      id\n      name\n      contentUrl\n      live\n      area {\n        id\n        name\n        urlName\n        country {\n          id\n          name\n          urlCode\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    pick {\n      id\n      blurb\n      __typename\n    }\n    __typename\n  }\n  __typename\n}\n"
    }

    response = requests.post('https://ra.co/graphql', json=json_data, headers=headers)

    # Extracting the events
    events = response.json()['data']['listing']['data']

    # Looping through the events to flatten the nested structure
    for event in events:
        flat_event = {
            'id': event['id'],
            'title': event['title'],
            'attending': event['attending'],
            'date': event['date'],
            'startTime': event['startTime'],
            'contentUrl': event['contentUrl'],
            'queueItEnabled': event['queueItEnabled'],
            'flyerFront': event['flyerFront'],
            'newEventForm': event['newEventForm'],
            'venue_id': event['venue']['id'],
            'venue_name': event['venue']['name'],
            'venue_contentUrl': event['venue']['contentUrl'],
            'venue_live': event['venue']['live'],
            'area_id': event['venue']['area']['id'],
            'area_name': event['venue']['area']['name'],
            'country_id': event['venue']['area']['country']['id'],
            'country_name': event['venue']['area']['country']['name'],
            'club_name': club_name  # Adding club name for reference
        }

        # Concatenating artist names
        artist_names = ', '.join([artist['name'] for artist in event['artists']])
        flat_event['artists'] = artist_names

        # Adding the flattened event to the list
        flattened_events.append(flat_event)
        time.sleep(2)


# Creating a DataFrame from the flattened events
df = pd.DataFrame(flattened_events)
df = df[['startTime', 'title', 'venue_name', 'contentUrl']].copy()
df['startTime'] = pd.to_datetime(df['startTime']).dt.strftime('%Y-%m-%d %H:%M:%S')
df['contentUrl'] = 'https://ra.co' + df['contentUrl']
df.rename(columns={'startTime': 'date_and_time','title': 'name', 'venue_name': 'location', 'contentUrl': 'url'}, inplace=True)
df.to_csv('../data/ra_test.csv', index=False)

# %%
    response = requests.post('https://ra.co/graphql', json=json_data, headers=headers)

    # Extracting the events
    events = response.json()['data']['listing']['data']

    # Looping through the events to flatten the nested structure
    for event in events:
        flat_event = {
            'id': event['id'],
            'title': event['title'],
            'attending': event['attending'],
            'date': event['date'],
            'startTime': event['startTime'],
            'contentUrl': event['contentUrl'],
            'queueItEnabled': event['queueItEnabled'],
            'flyerFront': event['flyerFront'],
            'newEventForm': event['newEventForm'],
            'venue_id': event['venue']['id'],
            'venue_name': event['venue']['name'],
            'venue_contentUrl': event['venue']['contentUrl'],
            'venue_live': event['venue']['live'],
            'area_id': event['venue']['area']['id'],
            'area_name': event['venue']['area']['name'],
            'country_id': event['venue']['area']['country']['id'],
            'country_name': event['venue']['area']['country']['name'],
            'club_name': club_name  # Adding club name for reference
        }

        # Concatenating artist names
        artist_names = ', '.join([artist['name'] for artist in event['artists']])
        flat_event['artists'] = artist_names

        # Adding the flattened event to the list
        flattened_events.append(flat_event)
        time.sleep(2)


# Creating a DataFrame from the flattened events
df = pd.DataFrame(flattened_events)
df = df[['startTime', 'title', 'venue_name', 'contentUrl']].copy()
df['startTime'] = pd.to_datetime(df['startTime']).dt.strftime('%Y-%m-%d %H:%M:%S')
df['contentUrl'] = 'https://ra.co' + df['contentUrl']
df.rename(columns={'startTime': 'date_and_time','title': 'name', 'venue_name': 'location', 'contentUrl': 'url'}, inplace=True)
df.to_csv('../data/ra_test.csv', index=False)
